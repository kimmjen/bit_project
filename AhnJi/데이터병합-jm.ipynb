# %%
from IPython.display import display
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import mglearn
plt.rcParams['axes.unicode_minus'] = False

import platform
path = 'c:/Windows/Fonts/malgun.ttf'
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~~')
# Out:
# D:\python2020\lib\site-packages\sklearn\externals\six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# D:\python2020\lib\site-packages\sklearn\externals\joblib\__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
data1 = pd.read_csv('final_data.csv',encoding='utf8')

# %%
data3 = pd.read_csv("IBK 크롤링-jm.csv",encoding='utf8', sep=',')

# %%
data1
# Out:
#       Unnamed: 0                 날짜     언론사  \
# 0              0   2020.06.01 08:41    매일경제
# 1              1   2020.06.01 04:03    매일경제
# 2              2   2020.05.31 14:17    조선비즈
# 3              3   2020.05.31 13:30    서울경제
# 4              4   2020.05.31 13:00  파이낸셜뉴스
# ...          ...                ...     ...
# 1805        1899   2019.06.18 10:48    한국경제
# 1806        1900   2019.06.18 10:12    한국경제
# 1807        1901   2019.06.18 05:37   머니투데이
# 1808        1902   2019.06.18 05:35   머니투데이
# 1809        1903   2019.06.17 05:40   머니투데이
#
#                                        기사제목  \
# 0            기업은행, 국내 첫 음성본인확인(Voice ID) 도입
# 1              IBK기업은행, 앱 하나면 대출·상권분석·회계 해결
# 2            기업은행, 목소리로 본인 확인하는 서비스 국내 첫 도입
# 3      "15초 안에 목소리로 본인 확인"···기업은행 음성본인확인 도입
# 4                    기업은행 음성본인확인서비스 국내최초 도입
# ...                                     ...
# 1805               IBK기업은행, 스마트 여신약정 서비스 시행
# 1806            기업은행, ‘IBK 스마트 여신약정 서비스’ 시행
# ...

# %%
data3
# Out:
#       Unnamed: 0        date  close  diff   open   high    low   volume  \
# 0              1  2020-06-02   9000   520   8470   9050   8460  5531440
# 1              2  2020-06-01   8480   200   8300   8500   8300  2861703
# 2              3  2020-05-29   8280    40   8110   8400   8030  4819669
# 3              4  2020-05-28   8240   280   8170   8380   8060  7549725
# 4              5  2020-05-27   7960   190   7860   7990   7810  4295846
# ...          ...         ...    ...   ...    ...    ...    ...      ...
# 2555        3834  2010-01-21  14200   150  14200  14450  14100  1208311
# 2556        3835  2010-01-20  14350   400  14850  14850  14200  2113118
# 2557        3836  2010-01-19  14750   300  14400  14900  14350  1845561
# 2558        3837  2010-01-18  14450   100  14250  14550  14000  1084530
# 2559        3838  2010-01-15  14350   150  14250  14500  14150  1137035
#
#       diff+- up/down
# 0      520.0       1
# 1      200.0       1
# 2       40.0       1
# ...

# %%
import datetime

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1810 entries, 0 to 1809
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1810 non-null   int64
#  1   날짜          1810 non-null   object
#  2   언론사         1810 non-null   object
#  3   기사제목        1810 non-null   object
#  4   기사내용        1810 non-null   object
#  5   링크          1810 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 85.0+ KB

# %%
data1['datetime'] = data1['날짜'].apply(lambda x:  pd.to_datetime(str(x), format='%Y-%m-%d'))

# %%
import datetime

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1810 entries, 0 to 1809
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1810 non-null   int64
#  1   날짜          1810 non-null   object
#  2   언론사         1810 non-null   object
#  3   기사제목        1810 non-null   object
#  4   기사내용        1810 non-null   object
#  5   링크          1810 non-null   object
#  6   datetime    1810 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 99.1+ KB

# %%
data1['datetime'] = data1['datetime'].dt.date

# %%
data1
# Out:
#       Unnamed: 0                 날짜     언론사  \
# 0              0   2020.06.01 08:41    매일경제
# 1              1   2020.06.01 04:03    매일경제
# 2              2   2020.05.31 14:17    조선비즈
# 3              3   2020.05.31 13:30    서울경제
# 4              4   2020.05.31 13:00  파이낸셜뉴스
# ...          ...                ...     ...
# 1805        1899   2019.06.18 10:48    한국경제
# 1806        1900   2019.06.18 10:12    한국경제
# 1807        1901   2019.06.18 05:37   머니투데이
# 1808        1902   2019.06.18 05:35   머니투데이
# 1809        1903   2019.06.17 05:40   머니투데이
#
#                                        기사제목  \
# 0            기업은행, 국내 첫 음성본인확인(Voice ID) 도입
# 1              IBK기업은행, 앱 하나면 대출·상권분석·회계 해결
# 2            기업은행, 목소리로 본인 확인하는 서비스 국내 첫 도입
# 3      "15초 안에 목소리로 본인 확인"···기업은행 음성본인확인 도입
# 4                    기업은행 음성본인확인서비스 국내최초 도입
# ...                                     ...
# 1805               IBK기업은행, 스마트 여신약정 서비스 시행
# 1806            기업은행, ‘IBK 스마트 여신약정 서비스’ 시행
# ...

# %%
data3.info()

# %%
data3['datetime'] = data3['date'].apply(lambda x: pd.to_datetime(str(x), format='%Y-%m-%d'))

# %%
data1.set_index(data1['datetime'], inplace=True)
data3.set_index(data3['datetime'], inplace=True)

# %%
data1 = data1.drop('datetime', 1)
data1 = data1.drop('Unnamed: 0', 1)

# %%
data1
# Out:
#                            날짜     언론사                                   기사제목  \
# datetime
# 2020-06-01   2020.06.01 08:41    매일경제         기업은행, 국내 첫 음성본인확인(Voice ID) 도입
# 2020-06-01   2020.06.01 04:03    매일경제           IBK기업은행, 앱 하나면 대출·상권분석·회계 해결
# 2020-05-31   2020.05.31 14:17    조선비즈         기업은행, 목소리로 본인 확인하는 서비스 국내 첫 도입
# 2020-05-31   2020.05.31 13:30    서울경제   "15초 안에 목소리로 본인 확인"···기업은행 음성본인확인 도입
# 2020-05-31   2020.05.31 13:00  파이낸셜뉴스                 기업은행 음성본인확인서비스 국내최초 도입
# ...                       ...     ...                                    ...
# 2019-06-18   2019.06.18 10:48    한국경제               IBK기업은행, 스마트 여신약정 서비스 시행
# 2019-06-18   2019.06.18 10:12    한국경제            기업은행, ‘IBK 스마트 여신약정 서비스’ 시행
# 2019-06-18   2019.06.18 05:37   머니투데이         IBK기업은행, 亞 최고 중소기업금융 리더 '큰 그림'
# 2019-06-18   2019.06.18 05:35   머니투데이  'IBK인도네시아은행' 뜬다…기업銀, 'IBK아시아벨트' 본격 가동
# 2019-06-17   2019.06.17 05:40   머니투데이          IBK기업은행 "기술력만 있으면…" 든든한 금융동반자
#
# ...

# %%
data3 = data3.drop('datetime', 1)

# %%
data4 = pd.merge(data1, data3,left_index=True, right_index=True, how='left')

# %%
data4.index
# Out:
# DatetimeIndex(['2019-06-17', '2019-06-18', '2019-06-18', '2019-06-18',
#                '2019-06-18', '2019-06-18', '2019-06-18', '2019-06-19',
#                '2019-06-19', '2019-06-19',
#                ...
#                '2020-05-27', '2020-05-27', '2020-05-27', '2020-05-28',
#                '2020-05-31', '2020-05-31', '2020-05-31', '2020-05-31',
#                '2020-06-01', '2020-06-01'],
#               dtype='datetime64[ns]', name='datetime', length=1810, freq=None)

# %%
data4
# Out:
#                            날짜     언론사                                  기사제목  \
# datetime
# 2019-06-17   2019.06.17 05:40   머니투데이         IBK기업은행 "기술력만 있으면…" 든든한 금융동반자
# 2019-06-18   2019.06.18 15:02    매일경제           기업은행, `IBK 스마트 여신약정 서비스` 시행
# 2019-06-18   2019.06.18 10:50   아시아경제              기업은행, IBK스마트 여신약정 서비스 시행
# 2019-06-18   2019.06.18 10:48    한국경제              IBK기업은행, 스마트 여신약정 서비스 시행
# 2019-06-18   2019.06.18 10:12    한국경제           기업은행, ‘IBK 스마트 여신약정 서비스’ 시행
# ...                       ...     ...                                   ...
# 2020-05-31   2020.05.31 13:30    서울경제  "15초 안에 목소리로 본인 확인"···기업은행 음성본인확인 도입
# 2020-05-31   2020.05.31 13:00  파이낸셜뉴스                기업은행 음성본인확인서비스 국내최초 도입
# 2020-05-31   2020.05.31 09:45    이데일리          IBK기업은행, 국내 최초 음성본인확인 서비스 도입
# 2020-06-01   2020.06.01 08:41    매일경제        기업은행, 국내 첫 음성본인확인(Voice ID) 도입
# 2020-06-01   2020.06.01 04:03    매일경제          IBK기업은행, 앱 하나면 대출·상권분석·회계 해결
#
# ...

# %%
#data_base=pd.merge(data1,data3, on = 'datetime')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-0baac9d8be39> in <module>
# ----> 1 data_base=pd.merge(data1,data3, on = 'datetime')
#
# D:\python2020\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      84         copy=copy,
#      85         indicator=indicator,
# ---> 86         validate=validate,
#      87     )
#      88     return op.get_result()
#
# D:\python2020\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     629         # validate the merge keys dtypes. We may need to coerce
#     630         # to avoid incompat dtypes
# --> 631         self._maybe_coerce_merge_keys()
#     632
# ...

# %%
data4.to_csv("ibk주가통합본-jm1.csv")

# %%
data3.loc['2020-06-01']
# Out:
#             Unnamed: 0        date  close  diff  open  high   low   volume  \
# datetime
# 2020-06-01           2  2020-06-01   8480   200  8300  8500  8300  2861703
#
#             diff+- up/down
# datetime
# 2020-06-01   200.0       1

# %%
data1edklf = pd.read_csv("ibk주가통합본-jm1.csv",encoding='utf8')

# %%
data1edklf
# Out:
#         datetime                 날짜     언론사  \
# 0     2019-06-17   2019.06.17 05:40   머니투데이
# 1     2019-06-18   2019.06.18 15:02    매일경제
# 2     2019-06-18   2019.06.18 10:50   아시아경제
# 3     2019-06-18   2019.06.18 10:48    한국경제
# 4     2019-06-18   2019.06.18 10:12    한국경제
# ...          ...                ...     ...
# 1805  2020-05-31   2020.05.31 13:30    서울경제
# 1806  2020-05-31   2020.05.31 13:00  파이낸셜뉴스
# 1807  2020-05-31   2020.05.31 09:45    이데일리
# 1808  2020-06-01   2020.06.01 08:41    매일경제
# 1809  2020-06-01   2020.06.01 04:03    매일경제
#
#                                       기사제목  \
# 0            IBK기업은행 "기술력만 있으면…" 든든한 금융동반자
# 1              기업은행, `IBK 스마트 여신약정 서비스` 시행
# 2                 기업은행, IBK스마트 여신약정 서비스 시행
# 3                 IBK기업은행, 스마트 여신약정 서비스 시행
# 4              기업은행, ‘IBK 스마트 여신약정 서비스’ 시행
# ...                                    ...
# 1805  "15초 안에 목소리로 본인 확인"···기업은행 음성본인확인 도입
# 1806                기업은행 음성본인확인서비스 국내최초 도입
# ...

# %%
data5

# %%
data4['up/down'].count
# Out:
# <bound method Series.count of datetime
# 2019-06-17      0
# 2019-06-18      1
# 2019-06-18      1
# 2019-06-18      1
# 2019-06-18      1
#              ...
# 2020-05-31    NaN
# 2020-05-31    NaN
# 2020-05-31    NaN
# 2020-06-01      1
# 2020-06-01      1
# Name: up/down, Length: 1810, dtype: object>

# %%
data_base.to_csv("ibk주가통합본.csv")

# %%
data4['20190420']

# %%
pd.value_counts(data4['up/down'].values, sort=False)
# Out:
# 0       882
# 1       643
# none    173
# dtype: int64

# %%
data_base.index

# %%
#none값제거
idx_1 = data_base[data_base['up/down'] == 'none'].index
data_base2 = data_base.drop(idx_1)
data_base2

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
my_words = []
for a_line in data_base2['content']:
    my_words += twitter.nouns(a_line)

# %%
# 단음절 제거.
my_words_2 = []
for a_word in my_words:
    if len(a_word) > 1:
        my_words_2 += [a_word]

# %%
# Series 로 변환.
my_series = pd.Series(my_words_2)

# %%
# 도수 분포표. Top 20
my_word_counts = my_series.value_counts().sort_values(ascending=False)
my_word_counts[:20]
